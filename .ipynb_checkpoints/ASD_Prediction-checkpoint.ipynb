# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import arff
from io import BytesIO
import math
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, plot_confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Process Datasets

# %% [markdown]
# ## 1. Create Data Frame

# %%
#create data frame for Child
data = arff.loadarff('Autism-Child-Data.arff')
df_child = pd.DataFrame(data[0])

# %%
df_child
# Out:
#     A1_Score A2_Score A3_Score A4_Score A5_Score A6_Score A7_Score A8_Score  \
# 0       b'1'     b'1'     b'0'     b'0'     b'1'     b'1'     b'0'     b'1'
# 1       b'1'     b'1'     b'0'     b'0'     b'1'     b'1'     b'0'     b'1'
# 2       b'1'     b'1'     b'0'     b'0'     b'0'     b'1'     b'1'     b'1'
# 3       b'0'     b'1'     b'0'     b'0'     b'1'     b'1'     b'0'     b'0'
# 4       b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 287     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'
# 288     b'1'     b'0'     b'0'     b'0'     b'1'     b'0'     b'1'     b'0'
# 289     b'1'     b'0'     b'1'     b'1'     b'1'     b'1'     b'1'     b'0'
# 290     b'1'     b'1'     b'1'     b'0'     b'1'     b'1'     b'1'     b'1'
# 291     b'0'     b'0'     b'1'     b'0'     b'1'     b'0'     b'1'     b'0'
#
#     A9_Score A10_Score  ...  gender           ethnicity jundice  austim  \
# 0       b'0'      b'0'  ...    b'm'           b'Others'   b'no'   b'no'
# 1       b'0'      b'0'  ...    b'm'  b'Middle Eastern '   b'no'   b'no'
# 2       b'0'      b'0'  ...    b'm'                b'?'   b'no'   b'no'
# 3       b'0'      b'1'  ...    b'f'                b'?'  b'yes'   b'no'
# 4       b'1'      b'1'  ...    b'm'           b'Others'  b'yes'   b'no'
# ..       ...       ...  ...     ...                 ...     ...     ...
# 287     b'1'      b'1'  ...    b'f'   b'White-European'  b'yes'  b'yes'
# 288     b'0'      b'1'  ...    b'f'   b'White-European'  b'yes'  b'yes'
# 289     b'0'      b'1'  ...    b'm'           b'Latino'   b'no'   b'no'
# 290     b'1'      b'1'  ...    b'm'      b'South Asian'   b'no'   b'no'
# 291     b'0'      b'0'  ...    b'f'      b'South Asian'   b'no'   b'no'
#
#          contry_of_res used_app_before result       age_desc   relation  \
# 0            b'Jordan'           b'no'    5.0  b'4-11 years'  b'Parent'
# 1            b'Jordan'           b'no'    5.0  b'4-11 years'  b'Parent'
# 2            b'Jordan'          b'yes'    5.0  b'4-11 years'       b'?'
# 3            b'Jordan'           b'no'    4.0  b'4-11 years'       b'?'
# 4     b'United States'           b'no'   10.0  b'4-11 years'  b'Parent'
# ..                 ...             ...    ...            ...        ...
# 287  b'United Kingdom'           b'no'   10.0  b'4-11 years'  b'Parent'
# 288       b'Australia'           b'no'    4.0  b'4-11 years'  b'Parent'
# 289          b'Brazil'           b'no'    7.0  b'4-11 years'  b'Parent'
# 290           b'India'           b'no'    9.0  b'4-11 years'  b'Parent'
# 291           b'India'           b'no'    3.0  b'4-11 years'  b'Parent'
#
#     Class/ASD
# 0       b'NO'
# 1       b'NO'
# 2       b'NO'
# 3       b'NO'
# 4      b'YES'
# ..        ...
# 287    b'YES'
# 288     b'NO'
# 289    b'YES'
# 290    b'YES'
# 291     b'NO'
#
# [292 rows x 21 columns]

# %%
#data type of each feature in the dataset
df_child.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   A1_Score         292 non-null    object
#  1   A2_Score         292 non-null    object
#  2   A3_Score         292 non-null    object
#  3   A4_Score         292 non-null    object
#  4   A5_Score         292 non-null    object
#  5   A6_Score         292 non-null    object
#  6   A7_Score         292 non-null    object
#  7   A8_Score         292 non-null    object
#  8   A9_Score         292 non-null    object
#  9   A10_Score        292 non-null    object
#  10  age              288 non-null    float64
#  11  gender           292 non-null    object
#  12  ethnicity        292 non-null    object
#  13  jundice          292 non-null    object
#  14  austim           292 non-null    object
#  15  contry_of_res    292 non-null    object
#  16  used_app_before  292 non-null    object
#  17  result           292 non-null    float64
#  18  age_desc         292 non-null    object
#  19  relation         292 non-null    object
#  20  Class/ASD        292 non-null    object
# dtypes: float64(2), object(19)
# memory usage: 48.0+ KB

# %% [markdown]
# ## 2. Drop Unrelated Features

# %%
df_child_drop = df_child.drop(['ethnicity','contry_of_res', 'age_desc'], axis=1)

# %%
df_child_drop
# Out:
#     A1_Score A2_Score A3_Score A4_Score A5_Score A6_Score A7_Score A8_Score  \
# 0       b'1'     b'1'     b'0'     b'0'     b'1'     b'1'     b'0'     b'1'
# 1       b'1'     b'1'     b'0'     b'0'     b'1'     b'1'     b'0'     b'1'
# 2       b'1'     b'1'     b'0'     b'0'     b'0'     b'1'     b'1'     b'1'
# 3       b'0'     b'1'     b'0'     b'0'     b'1'     b'1'     b'0'     b'0'
# 4       b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 287     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'     b'1'
# 288     b'1'     b'0'     b'0'     b'0'     b'1'     b'0'     b'1'     b'0'
# 289     b'1'     b'0'     b'1'     b'1'     b'1'     b'1'     b'1'     b'0'
# 290     b'1'     b'1'     b'1'     b'0'     b'1'     b'1'     b'1'     b'1'
# 291     b'0'     b'0'     b'1'     b'0'     b'1'     b'0'     b'1'     b'0'
#
#     A9_Score A10_Score  age gender jundice  austim used_app_before  result  \
# 0       b'0'      b'0'  6.0   b'm'   b'no'   b'no'           b'no'     5.0
# 1       b'0'      b'0'  6.0   b'm'   b'no'   b'no'           b'no'     5.0
# 2       b'0'      b'0'  6.0   b'm'   b'no'   b'no'          b'yes'     5.0
# 3       b'0'      b'1'  5.0   b'f'  b'yes'   b'no'           b'no'     4.0
# 4       b'1'      b'1'  5.0   b'm'  b'yes'   b'no'           b'no'    10.0
# ..       ...       ...  ...    ...     ...     ...             ...     ...
# 287     b'1'      b'1'  7.0   b'f'  b'yes'  b'yes'           b'no'    10.0
# 288     b'0'      b'1'  7.0   b'f'  b'yes'  b'yes'           b'no'     4.0
# 289     b'0'      b'1'  4.0   b'm'   b'no'   b'no'           b'no'     7.0
# 290     b'1'      b'1'  4.0   b'm'   b'no'   b'no'           b'no'     9.0
# 291     b'0'      b'0'  4.0   b'f'   b'no'   b'no'           b'no'     3.0
#
#       relation Class/ASD
# 0    b'Parent'     b'NO'
# 1    b'Parent'     b'NO'
# 2         b'?'     b'NO'
# 3         b'?'     b'NO'
# 4    b'Parent'    b'YES'
# ..         ...       ...
# 287  b'Parent'    b'YES'
# 288  b'Parent'     b'NO'
# 289  b'Parent'    b'YES'
# 290  b'Parent'    b'YES'
# 291  b'Parent'     b'NO'
#
# [292 rows x 18 columns]

# %% [markdown]
# ## 3. Translate Bytes Object

# %%
df_child_remove = df_child_drop

# %%
df_child_remove = df_child_remove.select_dtypes([object])
df_child_remove = df_child_remove.stack().str.decode('utf-8').unstack()

# %%
df_child_remove = df_child[['result','age']].join(df_child_remove)

# %%
df_child_remove
# Out:
#      result  age A1_Score A2_Score A3_Score A4_Score A5_Score A6_Score  \
# 0       5.0  6.0        1        1        0        0        1        1
# 1       5.0  6.0        1        1        0        0        1        1
# 2       5.0  6.0        1        1        0        0        0        1
# 3       4.0  5.0        0        1        0        0        1        1
# 4      10.0  5.0        1        1        1        1        1        1
# ..      ...  ...      ...      ...      ...      ...      ...      ...
# 287    10.0  7.0        1        1        1        1        1        1
# 288     4.0  7.0        1        0        0        0        1        0
# 289     7.0  4.0        1        0        1        1        1        1
# 290     9.0  4.0        1        1        1        0        1        1
# 291     3.0  4.0        0        0        1        0        1        0
#
#     A7_Score A8_Score A9_Score A10_Score gender jundice austim  \
# 0          0        1        0         0      m      no     no
# 1          0        1        0         0      m      no     no
# 2          1        1        0         0      m      no     no
# 3          0        0        0         1      f     yes     no
# 4          1        1        1         1      m     yes     no
# ..       ...      ...      ...       ...    ...     ...    ...
# 287        1        1        1         1      f     yes    yes
# 288        1        0        0         1      f     yes    yes
# 289        1        0        0         1      m      no     no
# 290        1        1        1         1      m      no     no
# 291        1        0        0         0      f      no     no
#
#     used_app_before relation Class/ASD
# 0                no   Parent        NO
# 1                no   Parent        NO
# 2               yes        ?        NO
# 3                no        ?        NO
# 4                no   Parent       YES
# ..              ...      ...       ...
# 287              no   Parent       YES
# 288              no   Parent        NO
# 289              no   Parent       YES
# 290              no   Parent       YES
# 291              no   Parent        NO
#
# [292 rows x 18 columns]

# %% [markdown]
# ## 4. One-Hot-Encoding
# #### Convert not numeric data to numeric for analysis purpose

# %%
df_child_onehot = df_child_remove.copy()

# %%
#Check the different values each feature has
for feature in df_child_remove:
    unique_value = df_child_remove[feature].unique()
    print(feature + " has value: ", unique_value )
# Out:
# result has value:  [ 5.  4. 10.  7.  8.  3.  9.  2.  1.  6.  0.]
# age has value:  [ 6.  5.  4. 11. 10.  8.  7.  9. nan]
# A1_Score has value:  ['1' '0']
# A2_Score has value:  ['1' '0']
# A3_Score has value:  ['0' '1']
# A4_Score has value:  ['0' '1']
# A5_Score has value:  ['1' '0']
# A6_Score has value:  ['1' '0']
# A7_Score has value:  ['0' '1']
# A8_Score has value:  ['1' '0']
# A9_Score has value:  ['0' '1']
# A10_Score has value:  ['0' '1']
# gender has value:  ['m' 'f']
# jundice has value:  ['no' 'yes']
# austim has value:  ['no' 'yes']
# used_app_before has value:  ['no' 'yes']
# relation has value:  ['Parent' '?' 'Self' 'Relative' 'Health care professional' 'self']
# Class/ASD has value:  ['NO' 'YES']

# %%
#do one-hot-encoing for each feature 
df_child_onehot['gender'] = df_child_onehot['gender'].map({'m': 0, 'f': 1})
df_child_onehot['jundice'] = df_child_onehot['jundice'].map({'no': 0, 'yes': 1})
df_child_onehot['austim'] = df_child_onehot['austim'].map({'no': 0, 'yes': 1})
df_child_onehot['used_app_before'] = df_child_onehot['used_app_before'].map({'no': 0, 'yes': 1})
df_child_onehot['relation'] = df_child_onehot['relation'].map({'Parent': 0, 'Self': 1, 'self': 1, 'Relative': 2, 'Health care professional': 3})
df_child_onehot['A1_Score'] = df_child_onehot['A1_Score'].map({'0': 0, '1': 1})
df_child_onehot['A2_Score'] = df_child_onehot['A2_Score'].map({'0': 0, '1': 1})
df_child_onehot['A3_Score'] = df_child_onehot['A3_Score'].map({'0': 0, '1': 1})
df_child_onehot['A4_Score'] = df_child_onehot['A4_Score'].map({'0': 0, '1': 1})
df_child_onehot['A5_Score'] = df_child_onehot['A5_Score'].map({'0': 0, '1': 1})
df_child_onehot['A6_Score'] = df_child_onehot['A6_Score'].map({'0': 0, '1': 1})
df_child_onehot['A7_Score'] = df_child_onehot['A7_Score'].map({'0': 0, '1': 1})
df_child_onehot['A8_Score'] = df_child_onehot['A8_Score'].map({'0': 0, '1': 1})
df_child_onehot['A9_Score'] = df_child_onehot['A9_Score'].map({'0': 0, '1': 1})
df_child_onehot['A10_Score'] = df_child_onehot['A10_Score'].map({'0': 0, '1': 1})

unique_value_ASD = df_child_onehot['Class/ASD'].unique()
val_no = unique_value[0]
val_yes = unique_value[1]
df_child_onehot['Class/ASD'] = df_child_onehot['Class/ASD'].map({val_no: 0, val_yes: 1})

#df_child_onehot['Class/ASD'] = df_child_remove['jundice'].map({'NO': 0, 'YES': 1})

# %% [markdown]
# ## 5. Handle Missing Value

# %%
df_child_onehot[df_child_onehot.isna().sum(axis=1) > 0]
# Out:
#      result   age  A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  \
# 2       5.0   6.0         1         1         0         0         0         1
# 3       4.0   5.0         0         1         0         0         1         1
# 5       5.0   4.0         0         0         1         0         1         1
# 9       5.0  11.0         0         0         1         1         1         0
# 11      3.0   5.0         0         1         0         0         1         0
# 19      8.0   5.0         1         1         1         1         1         1
# 21      5.0   9.0         0         0         1         1         0         1
# 24      8.0  11.0         1         0         1         1         1         1
# 28      5.0   6.0         0         1         1         0         0         0
# 32      7.0   NaN         1         0         0         1         0         1
# 36      3.0   4.0         0         1         0         0         1         0
# 40      6.0   5.0         0         0         1         1         1         1
# 43      8.0   4.0         1         0         1         1         1         1
# 47      7.0   6.0         1         1         1         0         1         0
# 50      4.0   7.0         0         1         0         0         1         0
# 52      6.0   6.0         1         0         0         1         0         1
# 54      5.0   5.0         1         0         1         1         0         1
# 56      2.0   6.0         0         0         1         0         0         1
# 65      1.0   NaN         0         0         1         0         0         0
# 68      5.0   4.0         0         0         1         0         1         1
# 110     7.0   5.0         0         1         1         1         1         0
# 123     5.0   4.0         0         1         1         0         0         1
# 126     7.0   NaN         1         1         1         1         0         1
# 138     6.0   NaN         0         1         1         0         1         1
# 146     5.0   4.0         0         1         1         0         1         0
# 149     3.0   4.0         0         0         0         0         1         1
# 160     7.0  11.0         1         0         1         1         1         1
# 168     8.0   8.0         0         1         1         1         1         1
# 174     5.0   4.0         0         1         1         0         0         1
# 180     8.0   4.0         1         1         1         1         1         1
# 181     4.0   4.0         0         1         1         0         1         0
# 190     7.0   4.0         1         1         1         0         1         1
# 194     5.0   5.0         1         1         0         0         1         1
# 212     5.0   4.0         0         1         1         0         1         1
# 231     5.0   4.0         0         1         1         0         0         1
# 232     7.0   4.0         0         1         1         1         1         1
# 233     8.0   5.0         0         1         1         1         1         1
# 235     6.0   5.0         0         0         1         1         1         1
# 242     3.0   6.0         0         1         0         0         0         0
# 243     3.0   9.0         1         1         0         0         0         0
# 244     6.0   7.0         0         1         1         0         1         1
# 249     6.0   9.0         0         1         0         1         1         0
# 251     8.0   7.0         0         1         1         1         1         1
# 268     7.0  10.0         1         0         1         0         1         1
#
#      A7_Score  A8_Score  A9_Score  A10_Score  gender  jundice  austim  \
# 2           1         1         0          0       0        0       0
# 3           0         0         0          1       1        1       0
# 5           0         1         0          1       0        0       1
# 9           1         1         0          0       1        0       1
# 11          0         0         0          1       1        0       0
# 19          0         1         0          1       0        0       0
# 21          0         1         1          0       1        0       0
# 24          0         1         1          1       0        0       0
# 28          1         1         0          1       0        0       1
# 32          1         1         1          1       0        0       0
# 36          0         1         0          0       1        0       0
# 40          0         1         0          1       0        1       0
# 43          0         1         1          1       1        0       0
# 47          1         1         0          1       0        0       0
# 50          1         0         0          1       0        1       0
# 52          0         1         1          1       0        0       0
# 54          0         0         0          1       0        0       0
# 56          0         0         0          0       0        0       0
# 65          0         0         0          0       0        0       0
# 68          1         0         1          0       1        0       1
# 110         1         1         0          1       0        0       0
# 123         1         1         0          0       0        1       0
# 126         0         1         0          1       0        1       0
# 138         1         1         0          0       0        1       0
# 146         1         0         0          1       0        1       0
# 149         1         0         0          0       0        0       0
# 160         0         1         0          1       0        0       0
# 168         0         1         1          1       0        1       0
# 174         1         1         0          0       0        1       0
# 180         0         0         1          1       1        1       0
# 181         1         0         0          0       1        0       0
# 190         0         1         0          1       0        0       0
# 194         1         0         0          0       0        0       0
# 212         0         0         0          1       0        1       0
# 231         1         0         0          1       0        1       0
# 232         1         0         0          1       0        1       0
# 233         0         1         1          1       0        0       0
# 235         0         1         0          1       0        0       0
# 242         1         0         0          1       0        1       0
# 243         1         0         0          0       1        1       0
# 244         0         1         0          1       0        1       0
# 249         1         1         0          1       0        1       0
# 251         1         1         0          1       0        1       0
# 268         1         0         1          1       0        1       0
#
#      used_app_before  relation  Class/ASD
# 2                  1       NaN          0
# 3                  0       NaN          0
# 5                  0       NaN          0
# 9                  0       NaN          0
# 11                 0       NaN          0
# 19                 0       NaN          1
# 21                 0       NaN          0
# 24                 0       NaN          1
# 28                 0       NaN          0
# 32                 0       NaN          1
# 36                 0       NaN          0
# 40                 0       NaN          0
# 43                 0       NaN          1
# 47                 0       NaN          1
# 50                 0       NaN          0
# 52                 0       NaN          0
# 54                 0       NaN          0
# 56                 0       NaN          0
# 65                 0       0.0          0
# 68                 0       NaN          0
# 110                0       NaN          1
# 123                0       NaN          0
# 126                0       NaN          1
# 138                1       NaN          0
# 146                0       NaN          0
# 149                1       NaN          0
# 160                0       NaN          1
# 168                0       NaN          1
# 174                1       NaN          0
# 180                0       NaN          1
# 181                0       NaN          0
# 190                0       NaN          1
# 194                0       NaN          0
# 212                0       NaN          0
# 231                0       NaN          0
# 232                1       NaN          1
# 233                0       NaN          1
# 235                0       NaN          0
# 242                0       NaN          0
# 243                0       NaN          0
# 244                0       NaN          0
# 249                0       NaN          0
# 251                0       NaN          1
# 268                0       NaN          1

# %%
#fill missing value of 'relation' with 'Parents', since most questions are answered by children's Parents
df_child_onehot['relation'].fillna(value = 0, inplace=True)

#fill missing value of 'age' with its mean
df_child_onehot['age'].fillna(round(df_child_onehot['age'].mean()), inplace=True)

# %%
#check if all missing values are handeled
df_child_onehot[df_child_onehot.isna().sum(axis=1) > 0]
# Out:
# Empty DataFrame
# Columns: [result, age, A1_Score, A2_Score, A3_Score, A4_Score, A5_Score, A6_Score, A7_Score, A8_Score, A9_Score, A10_Score, gender, jundice, austim, used_app_before, relation, Class/ASD]
# Index: []

# %% [markdown]
# ## 6. Check if the data set is balaned or not

# %%
#find number of negative(-) class
num_of_negative = len(df_child_onehot[df_child_onehot['Class/ASD'] == 0])
num_of_negative
# Out:
# 151

# %%
#find number of postive(+) class
num_of_negative = len(df_child_onehot[df_child_onehot['Class/ASD'] == 1])
num_of_negative
# Out:
# 141

# %% [markdown]
# # Build Random Forest Model

# %% [markdown]
# ## 1. Split df_child_onehot into train and test sets

# %%
X = df_child_onehot.iloc[:, :-1]
y = df_child_onehot.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %% [markdown]
# ## 2. Train the model

# %%
model = RandomForestClassifier(n_estimators=1000)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000)

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %% [markdown]
# ## 2. Use Grid Search to Find Best Mtry and Ntree for RF Model

# %%
#get the number of features
num_feature = len(train_feature.columns)

# %%
#find three values of Mtry
mtry_1 = round(0.5 * math.sqrt(num_feature))
mtry_2 = round(math.sqrt(num_feature))
mtry_3 = round(2 * math.sqrt(num_feature))

# %%
#parameters list for tuning
mtry = [mtry_1, mtry_2, mtry_3]
ntree = [500,1000]

# %%
#do grid search 
for i in range (2):
    for j in range (3):
        nTree = ntree[i]
        mTry = mtry[j]
        #create a RF model
        model = RandomForestClassifier(n_estimators=nTree, max_features=mTry, oob_score= True, random_state = 0)
        #train the RF model
        model.fit(train_feature, train_label)
        #use decision funciton estimated on training set to find prediction based on training set
        prediction = np.argmax(model.oob_decision_function_, axis = 1)
        #print out ntree value and mtry value with their corresponding f1 score
        print("nTree = ", nTree, "     mTry = " , mTry)
        print("F1: ", f1_score(train_label, prediction))
        print("Accuracy: ", accuracy_score(train_label, prediction))
# Out:
# /var/folders/tl/3mf1sjy10xn0t7qcbvyvtd8r0000gn/T/ipykernel_79738/2464608381.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(train_feature, train_label)
# nTree =  500      mTry =  2
# F1:  1.0
# Accuracy:  1.0
# /var/folders/tl/3mf1sjy10xn0t7qcbvyvtd8r0000gn/T/ipykernel_79738/2464608381.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(train_feature, train_label)
# nTree =  500      mTry =  4
# F1:  1.0
# Accuracy:  1.0
# /var/folders/tl/3mf1sjy10xn0t7qcbvyvtd8r0000gn/T/ipykernel_79738/2464608381.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(train_feature, train_label)
# nTree =  500      mTry =  8
# F1:  1.0
# Accuracy:  1.0
# /var/folders/tl/3mf1sjy10xn0t7qcbvyvtd8r0000gn/T/ipykernel_79738/2464608381.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(train_feature, train_label)
# nTree =  1000      mTry =  2
# F1:  1.0
# Accuracy:  1.0
# /var/folders/tl/3mf1sjy10xn0t7qcbvyvtd8r0000gn/T/ipykernel_79738/2464608381.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(train_feature, train_label)
# nTree =  1000      mTry =  4
# F1:  1.0
# Accuracy:  1.0
# /var/folders/tl/3mf1sjy10xn0t7qcbvyvtd8r0000gn/T/ipykernel_79738/2464608381.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(train_feature, train_label)
# nTree =  1000      mTry =  8
# F1:  1.0
# Accuracy:  1.0
